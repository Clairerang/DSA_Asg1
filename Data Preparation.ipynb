# %%
import pandas as pd
import networkx as nx
#import folium
import matplotlib.pyplot as plt

# %%
AIRPORTS_FILE = "airports.dat"
ROUTES_FILE = "routes.dat"

# Load airports dataset
cols_airports = ["Airport ID", "Airport Name", "City", "IATA", "ICAO", "Latitude", "Longitude", "Altitude", 
                 "Timezone", "DST", "TzDatabaseTime", "Type", "Source"]

airports_df = pd.read_csv(AIRPORTS_FILE, header=None, names=cols_airports)

# Load routes dataset
cols_routes = ["Airline", "AirlineID", "SourceAirport", "SourceAirportID", 
               "DestinationAirport", "DestinationAirportID", "Codeshare", "Stops", "Equipment"]

routes_df = pd.read_csv(ROUTES_FILE, header=None, names=cols_routes)

# Display the first few rows
display(airports_df.head(), routes_df.head())
# Out:
#                                     Airport ID  Airport Name  \
# 1                               Goroka Airport        Goroka
# 2                               Madang Airport        Madang
# 3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 4                               Nadzab Airport        Nadzab
# 5  Port Moresby Jacksons International Airport  Port Moresby
#
#                City IATA  ICAO  Latitude   Longitude  Altitude Timezone DST  \
# 1  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 2  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20       10   U
# 3  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 4  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 5  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#          TzDatabaseTime     Type       Source
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports
# 5  Pacific/Port_Moresby  airport  OurAirports
#   Airline AirlineID SourceAirport SourceAirportID DestinationAirport  \
# 0      2B       410           AER            2965                KZN
# 1      2B       410           ASF            2966                KZN
# 2      2B       410           ASF            2966                MRV
# 3      2B       410           CEK            2968                KZN
# 4      2B       410           CEK            2968                OVB
#
#   DestinationAirportID Codeshare  Stops Equipment
# 0                 2990       NaN      0       CR2
# 1                 2990       NaN      0       CR2
# 2                 2962       NaN      0       CR2
# 3                 2990       NaN      0       CR2
# 4                 4078       NaN      0       CR2

# %%
print("Missing values in airports dataset:\n", airports_df.isnull().sum())
print("\nMissing values in routes dataset:\n", routes_df.isnull().sum())
# Out:
# Missing values in airports dataset:
#  Airport ID         0
# Airport Name      49
# City               0
# IATA               0
# ICAO               0
# Latitude           0
# Longitude          0
# Altitude           0
# Timezone           0
# DST                0
# TzDatabaseTime     0
# Type               0
# Source             0
# dtype: int64
#
# Missing values in routes dataset:
#  Airline                     0
# AirlineID                   0
# SourceAirport               0
# SourceAirportID             0
# DestinationAirport          0
# DestinationAirportID        0
# Codeshare               53066
# Stops                       0
# Equipment                  18
# dtype: int64

# %%
airports_df = airports_df.dropna(subset=["Airport Name"])

routes_df = routes_df.drop(columns=["Codeshare", "Equipment"])

print("Missing values in airports dataset:\n", airports_df.isnull().sum())
print("Missing values in routes dataset:\n", routes_df.isnull().sum())
# Out:
# Missing values in airports dataset:
#  Airport ID        0
# Airport Name      0
# City              0
# IATA              0
# ICAO              0
# Latitude          0
# Longitude         0
# Altitude          0
# Timezone          0
# DST               0
# TzDatabaseTime    0
# Type              0
# Source            0
# dtype: int64
# Missing values in routes dataset:
#  Airline                 0
# AirlineID               0
# SourceAirport           0
# SourceAirportID         0
# DestinationAirport      0
# DestinationAirportID    0
# Stops                   0
# dtype: int64

# %%
print("Total Airports:", len(airports_df))
print("Total Routes:", len(routes_df))
print("\nTop 10 busiest airports (by outgoing routes):")
print(routes_df["SourceAirport"].value_counts().head(10))
# Out:
# Total Airports: 7649
# Total Routes: 67663
#
# Top 10 busiest airports (by outgoing routes):
# SourceAirport
# ATL    915
# ORD    558
# PEK    535
# LHR    527
# CDG    524
# FRA    497
# LAX    492
# DFW    469
# JFK    456
# AMS    453
# Name: count, dtype: int64

# %%
# Convert invalid latitude and longitude values to NaN
airports_df["Latitude"] = pd.to_numeric(airports_df["Latitude"], errors="coerce")
airports_df["Longitude"] = pd.to_numeric(airports_df["Longitude"], errors="coerce")

# Drop rows where Latitude or Longitude is NaN
airports_df = airports_df.dropna(subset=["Latitude", "Longitude"])

print(f"Cleaned dataset: {len(airports_df)} airports remaining.")
# Out:
# Cleaned dataset: 7649 airports remaining.

# %%
# # Create a map centered at an approximate global location
# import folium
# world_map = folium.Map(location=[20, 0], zoom_start=2)

# # Add airport markers
# for _, row in airports_df.iterrows():
#     folium.CircleMarker(
#         location=[row["Latitude"], row["Longitude"]],
#         radius=2,
#         color="blue",
#         fill=True,
#         fill_color="blue",
#     ).add_to(world_map)

# # Save the map
# world_map.save("airport_distribution.html")
# print("Airport distribution map saved as 'airport_distribution.html'")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Create a map centered at an approximate global location
# ----> 2 import folium
#       3 world_map = folium.Map(location=[20, 0], zoom_start=2)
#       5 # Add airport markers
#
# ModuleNotFoundError: No module named 'folium'

# %%
def build_flight_graph(routes_df):
    """Builds a directed graph of the flight network."""
    G = nx.DiGraph()
    for _, row in routes_df.iterrows():
        G.add_edge(row["SourceAirport"], row["DestinationAirport"])
    return G

flight_graph = build_flight_graph(routes_df)

# Find the most connected airports (hubs)
degree_centrality = nx.degree_centrality(flight_graph)
top_hubs = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:10]
print("\nTop 10 hubs (most connected airports):")
for airport, centrality in top_hubs:
    print(f"Airport {airport}: {centrality:.4f}")
# Out:
# Top 10 hubs (most connected airports):
# Airport FRA: 0.1393
# Airport CDG: 0.1373
# Airport AMS: 0.1352
# Airport IST: 0.1335
# Airport ATL: 0.1265
# Airport PEK: 0.1203
# Airport ORD: 0.1195
# Airport MUC: 0.1110
# Airport DME: 0.1104
# Airport DFW: 0.1086

# %%
def find_shortest_route(graph, source, destination):
    """Finds the shortest path between two airports."""
    try:
        return nx.shortest_path(graph, source=str(source), target=str(destination))
    except nx.NetworkXNoPath:
        return None
    except nx.NodeNotFound:
        return None

source_airport = "507"  # Example: ATL (Atlanta)
destination_airport = "3797"  # Example: LAX (Los Angeles)

shortest_route = find_shortest_route(flight_graph, source_airport, destination_airport)
print("Shortest route:", shortest_route)
# Out:
# Shortest route: None

# %%
# Airports that have outbound flights but no inbound flights
outbound_airports = set(routes_df["SourceAirport"])
inbound_airports = set(routes_df["DestinationAirport"])
airports_with_no_incoming = outbound_airports - inbound_airports
airports_with_no_outgoing = inbound_airports - outbound_airports

print("Airports with only outbound flights:", len(airports_with_no_incoming))
print("Airports with only inbound flights:", len(airports_with_no_outgoing))
# Out:
# Airports with only outbound flights: 7
# Airports with only inbound flights: 16

# %%
from networkx.algorithms.community import greedy_modularity_communities

# Detect communities in the flight network
communities = greedy_modularity_communities(flight_graph)

print(f"Detected {len(communities)} airport clusters.")
print("Example of first community (first 10 airports):", list(communities[0])[:10])
# Out:
# Detected 46 airport clusters.
# Example of first community (first 10 airports): ['ASM', 'LNB', 'RXS', 'CPD', 'BYN', 'WJU', 'KUL', 'JZH', 'THL', 'NTL']

# %%
display(airports_df.head(50), routes_df.head(50))
# Out:
#                                      Airport ID        Airport Name  \
# 1                                Goroka Airport              Goroka
# 2                                Madang Airport              Madang
# 3                  Mount Hagen Kagamuga Airport         Mount Hagen
# 4                                Nadzab Airport              Nadzab
# 5   Port Moresby Jacksons International Airport        Port Moresby
# 6                   Wewak International Airport               Wewak
# 7                            Narsarsuaq Airport        Narssarssuaq
# 8                       Godthaab / Nuuk Airport            Godthaab
# 9                         Kangerlussuaq Airport         Sondrestrom
# 10                               Thule Air Base               Thule
# 11                             Akureyri Airport            Akureyri
# 12                          Egilsstaðir Airport         Egilsstadir
# 13                         Hornafjörður Airport                Hofn
# 14                              Húsavík Airport             Husavik
# 15                           Ísafjörður Airport          Isafjordur
# 16               Keflavik International Airport            Keflavik
# 17                       Patreksfjörður Airport      Patreksfjordur
# 18                            Reykjavik Airport           Reykjavik
# 19                         Siglufjörður Airport        Siglufjordur
# 20                       Vestmannaeyjar Airport      Vestmannaeyjar
# 21                      Sault Ste Marie Airport  Sault Sainte Marie
# 22               Winnipeg / St. Andrews Airport            Winnipeg
# 23            Halifax / CFB Shearwater Heliport             Halifax
# 24                          St. Anthony Airport         St. Anthony
# 25                  Tofino / Long Beach Airport              Tofino
# 26                             Kugaaruk Airport           Pelly Bay
# 27                          Baie Comeau Airport         Baie Comeau
# 28                               CFB Bagotville          Bagotville
# 29                           Baker Lake Airport          Baker Lake
# 30                       Campbell River Airport      Campbell River
# 31                    Brandon Municipal Airport             Brandon
# 32                        Cambridge Bay Airport       Cambridge Bay
# 33                              Nanaimo Airport             Nanaimo
# 34     Castlegar/West Kootenay Regional Airport           Castlegar
# 35                            Miramichi Airport             Chatham
# 36                               Charlo Airport              Charlo
# 37                            Kugluktuk Airport          Coppermine
# 38                           Coronation Airport          Coronation
# 39                           Chilliwack Airport          Chilliwack
# 40                          Clyde River Airport         Clyde River
# 41                        Coral Harbour Airport       Coral Harbour
# 42                          Dawson City Airport              Dawson
# 43                              Burwash Airport             Burwash
# 44                            Princeton Airport           Princeton
# 45                            Deer Lake Airport           Deer Lake
# 46                           Dease Lake Airport          Dease Lake
# 47                       Dauphin Barker Airport             Dauphin
# 48                         Dawson Creek Airport        Dawson Creek
# 49               Edmonton International Airport            Edmonton
# 50                               Arviat Airport        Eskimo Point
#
#                 City IATA  ICAO   Latitude   Longitude  Altitude Timezone DST  \
# 1   Papua New Guinea  GKA  AYGA  -6.081690  145.391998      5282       10   U
# 2   Papua New Guinea  MAG  AYMD  -5.207080  145.789001        20       10   U
# 3   Papua New Guinea  HGU  AYMH  -5.826790  144.296005      5388       10   U
# 4   Papua New Guinea  LAE  AYNZ  -6.569803  146.725977       239       10   U
# 5   Papua New Guinea  POM  AYPY  -9.443380  147.220001       146       10   U
# 6   Papua New Guinea  WWK  AYWK  -3.583830  143.669006        19       10   U
# 7          Greenland  UAK  BGBW  61.160500  -45.425999       112       -3   E
# 8          Greenland  GOH  BGGH  64.190903  -51.678101       283       -3   E
# 9          Greenland  SFJ  BGSF  67.012222  -50.711603       165       -3   E
# 10         Greenland  THU  BGTL  76.531197  -68.703201       251       -4   E
# 11           Iceland  AEY  BIAR  65.660004  -18.072701         6        0   N
# 12           Iceland  EGS  BIEG  65.283302  -14.401400        76        0   N
# 13           Iceland  HFN  BIHN  64.295601  -15.227200        24        0   N
# 14           Iceland  HZK  BIHU  65.952301  -17.426001        48        0   N
# 15           Iceland  IFJ  BIIS  66.058098  -23.135300         8        0   N
# 16           Iceland  KEF  BIKF  63.985001  -22.605600       171        0   N
# 17           Iceland  PFJ  BIPA  65.555801  -23.965000        11        0   N
# 18           Iceland  RKV  BIRK  64.129997  -21.940599        48        0   N
# 19           Iceland  SIJ  BISI  66.133301  -18.916700        10        0   N
# 20           Iceland  VEY  BIVM  63.424301  -20.278900       326        0   N
# 21            Canada  YAM  CYAM  46.485001  -84.509399       630       -5   A
# 22            Canada   \N  CYAV  50.056400  -97.032501       760       -6   A
# 23            Canada   \N  CYAW  44.639702  -63.499401       144       -4   A
# 24            Canada  YAY  CYAY  51.391899  -56.083099       108     -3.5   A
# 25            Canada  YAZ  CYAZ  49.079833 -125.775583        80       -8   A
# 26            Canada  YBB  CYBB  68.534401  -89.808098        56       -7   A
# 27            Canada  YBC  CYBC  49.132500  -68.204399        71       -5   A
# 28            Canada  YBG  CYBG  48.330601  -70.996399       522       -5   A
# 29            Canada  YBK  CYBK  64.298897  -96.077797        59       -6   A
# 30            Canada  YBL  CYBL  49.950802 -125.271004       346       -8   A
# 31            Canada  YBR  CYBR  49.910000  -99.951897      1343       -6   A
# 32            Canada  YCB  CYCB  69.108101 -105.138000        90       -7   A
# 33            Canada  YCD  CYCD  49.054970 -123.869863        92       -8   A
# 34            Canada  YCG  CYCG  49.296398 -117.632004      1624       -8   A
# 35            Canada  YCH  CYCH  47.007801  -65.449203       108       -4   A
# 36            Canada  YCL  CYCL  47.990799  -66.330299       132       -4   A
# 37            Canada  YCO  CYCO  67.816704 -115.143997        74       -7   A
# 38            Canada  YCT  CYCT  52.075001 -111.445000      2595       -7   A
# 39            Canada  YCW  CYCW  49.152802 -121.939003        32       -8   A
# 40            Canada  YCY  CYCY  70.486099  -68.516701        87       -5   A
# 41            Canada  YZS  CYZS  64.193298  -83.359398       210       -5   A
# 42            Canada  YDA  CYDA  64.043098 -139.128006      1215       -8   A
# 43            Canada  YDB  CYDB  61.371101 -139.041000      2647       -8   A
# 44            Canada   \N  CYDC  49.468102 -120.511002      2298       -8   A
# 45            Canada  YDF  CYDF  49.210800  -57.391399        72     -3.5   A
# 46            Canada  YDL  CYDL  58.422199 -130.031998      2600       -8   A
# 47            Canada  YDN  CYDN  51.100800 -100.052002       999       -6   A
# 48            Canada  YDQ  CYDQ  55.742298 -120.182999      2148       -7   A
# 49            Canada  YEG  CYEG  53.309700 -113.580002      2373       -7   A
# 50            Canada  YEK  CYEK  61.094200  -94.070801        32       -6   A
#
#            TzDatabaseTime     Type       Source
# 1    Pacific/Port_Moresby  airport  OurAirports
# 2    Pacific/Port_Moresby  airport  OurAirports
# 3    Pacific/Port_Moresby  airport  OurAirports
# 4    Pacific/Port_Moresby  airport  OurAirports
# 5    Pacific/Port_Moresby  airport  OurAirports
# 6    Pacific/Port_Moresby  airport  OurAirports
# 7         America/Godthab  airport  OurAirports
# 8         America/Godthab  airport  OurAirports
# 9         America/Godthab  airport  OurAirports
# 10          America/Thule  airport  OurAirports
# 11     Atlantic/Reykjavik  airport  OurAirports
# 12     Atlantic/Reykjavik  airport  OurAirports
# 13     Atlantic/Reykjavik  airport  OurAirports
# 14     Atlantic/Reykjavik  airport  OurAirports
# 15     Atlantic/Reykjavik  airport  OurAirports
# 16     Atlantic/Reykjavik  airport  OurAirports
# 17     Atlantic/Reykjavik  airport  OurAirports
# 18     Atlantic/Reykjavik  airport  OurAirports
# 19     Atlantic/Reykjavik  airport  OurAirports
# 20     Atlantic/Reykjavik  airport  OurAirports
# 21        America/Toronto  airport  OurAirports
# 22       America/Winnipeg  airport  OurAirports
# 23        America/Halifax  airport  OurAirports
# 24       America/St_Johns  airport  OurAirports
# 25      America/Vancouver  airport  OurAirports
# 26       America/Edmonton  airport  OurAirports
# 27        America/Toronto  airport  OurAirports
# 28        America/Toronto  airport  OurAirports
# 29       America/Winnipeg  airport  OurAirports
# 30      America/Vancouver  airport  OurAirports
# 31       America/Winnipeg  airport  OurAirports
# 32       America/Edmonton  airport  OurAirports
# 33      America/Vancouver  airport  OurAirports
# 34      America/Vancouver  airport  OurAirports
# 35        America/Halifax  airport  OurAirports
# 36        America/Halifax  airport  OurAirports
# 37       America/Edmonton  airport  OurAirports
# 38       America/Edmonton  airport  OurAirports
# 39      America/Vancouver  airport  OurAirports
# 40        America/Toronto  airport  OurAirports
# 41  America/Coral_Harbour  airport  OurAirports
# 42      America/Vancouver  airport  OurAirports
# 43      America/Vancouver  airport  OurAirports
# 44      America/Vancouver  airport  OurAirports
# 45       America/St_Johns  airport  OurAirports
# 46      America/Vancouver  airport  OurAirports
# 47       America/Winnipeg  airport  OurAirports
# 48   America/Dawson_Creek  airport  OurAirports
# 49       America/Edmonton  airport  OurAirports
# 50       America/Winnipeg  airport  OurAirports
#    Airline AirlineID SourceAirport SourceAirportID DestinationAirport  \
# 0       2B       410           AER            2965                KZN
# 1       2B       410           ASF            2966                KZN
# 2       2B       410           ASF            2966                MRV
# 3       2B       410           CEK            2968                KZN
# 4       2B       410           CEK            2968                OVB
# 5       2B       410           DME            4029                KZN
# 6       2B       410           DME            4029                NBC
# 7       2B       410           DME            4029                TGK
# 8       2B       410           DME            4029                UUA
# 9       2B       410           EGO            6156                KGD
# 10      2B       410           EGO            6156                KZN
# 11      2B       410           GYD            2922                NBC
# 12      2B       410           KGD            2952                EGO
# 13      2B       410           KZN            2990                AER
# 14      2B       410           KZN            2990                ASF
# 15      2B       410           KZN            2990                CEK
# 16      2B       410           KZN            2990                DME
# 17      2B       410           KZN            2990                EGO
# 18      2B       410           KZN            2990                LED
# 19      2B       410           KZN            2990                SVX
# 20      2B       410           LED            2948                KZN
# 21      2B       410           LED            2948                NBC
# 22      2B       410           LED            2948                UUA
# 23      2B       410           MRV            2962                ASF
# 24      2B       410           NBC            6969                DME
# 25      2B       410           NBC            6969                GYD
# 26      2B       410           NBC            6969                LED
# 27      2B       410           NBC            6969                SVX
# 28      2B       410           NJC            2972                SVX
# 29      2B       410           NJC            2972                UUA
# 30      2B       410           NUX            4364                SVX
# 31      2B       410           OVB            4078                CEK
# 32      2B       410           OVB            4078                SVX
# 33      2B       410           SVX            2975                KZN
# 34      2B       410           SVX            2975                NBC
# 35      2B       410           SVX            2975                NJC
# 36      2B       410           SVX            2975                NUX
# 37      2B       410           SVX            2975                OVB
# 38      2B       410           TGK              \N                DME
# 39      2B       410           UUA            6160                DME
# 40      2B       410           UUA            6160                LED
# 41      2B       410           UUA            6160                NJC
# 42      2G      1654           BTK            2936                IKT
# 43      2G      1654           BTK            2936                OVB
# 44      2G      1654           CEK            2968                OVB
# 45      2G      1654           HTA            2935                IKT
# 46      2G      1654           IKT            2937                BTK
# 47      2G      1654           IKT            2937                HTA
# 48      2G      1654           IKT            2937                KCK
# 49      2G      1654           IKT            2937                ODO
#
#    DestinationAirportID  Stops
# 0                  2990      0
# 1                  2990      0
# 2                  2962      0
# 3                  2990      0
# 4                  4078      0
# 5                  2990      0
# 6                  6969      0
# 7                    \N      0
# 8                  6160      0
# 9                  2952      0
# 10                 2990      0
# 11                 6969      0
# 12                 6156      0
# 13                 2965      0
# 14                 2966      0
# 15                 2968      0
# 16                 4029      0
# 17                 6156      0
# 18                 2948      0
# 19                 2975      0
# 20                 2990      0
# 21                 6969      0
# 22                 6160      0
# 23                 2966      0
# 24                 4029      0
# 25                 2922      0
# 26                 2948      0
# 27                 2975      0
# 28                 2975      0
# 29                 6160      0
# 30                 2975      0
# 31                 2968      0
# 32                 2975      0
# 33                 2990      0
# 34                 6969      0
# 35                 2972      0
# 36                 4364      0
# 37                 4078      0
# 38                 4029      0
# 39                 4029      0
# 40                 2948      0
# 41                 2972      0
# 42                 2937      0
# 43                 4078      0
# 44                 4078      0
# 45                 2937      0
# 46                 2936      0
# 47                 2935      0
# 48                   \N      0
# 49                 8944      0

# %%
AIRLINE_FILE = "airlines.dat"

airline_df = pd.read_csv(AIRLINE_FILE)

# %%
airline_df.head(50)
# Out:
#     -1                                       Unknown  \N    -  N/A  \
# 0    1                                Private flight  \N    -  NaN
# 1    2                                   135 Airways  \N  NaN  GNL
# 2    3                                 1Time Airline  \N   1T  RNX
# 3    4  2 Sqn No 1 Elementary Flying Training School  \N  NaN  WYT
# 4    5                               213 Flight Unit  \N  NaN  TFU
# 5    6                 223 Flight Unit State Airline  \N  NaN  CHD
# 6    7                             224th Flight Unit  \N  NaN  TTF
# 7    8                                   247 Jet Ltd  \N  NaN  TWF
# 8    9                                   3D Aviation  \N  NaN  SEC
# 9   10                                   40-Mile Air  \N   Q5  MLA
# 10  11                                        4D Air  \N  NaN  QRT
# 11  12                        611897 Alberta Limited  \N  NaN  THD
# 12  13                              Ansett Australia  \N   AN  AAA
# 13  14                          Abacus International  \N   1B  NaN
# 14  15                               Abelag Aviation  \N   W9  AAB
# 15  16                                Army Air Corps  \N  NaN  AAC
# 16  17                     Aero Aviation Centre Ltd.  \N  NaN  AAD
# 17  18     Aero Servicios Ejecutivos Internacionales  \N  NaN  SII
# 18  19                                   Aero Biniza  \N  NaN  BZS
# 19  20                                 Aero Albatros  \N  NaN  ABM
# 20  21                                    Aigle Azur  \N   ZI  AAF
# 21  22                                Aloha Airlines  \N   AQ  AAH
# 22  23                             Alaska Island Air  \N  NaN  AAK
# 23  24                             American Airlines  \N   AA  AAL
# 24  25               Aviation Management Corporation  \N  NaN  AAM
# 25  26                       Atlantis Airlines (USA)  \N  NaN  AAO
# 26  27                            Aerovista Airlines  \N  NaN  AAP
# 27  28                               Asiana Airlines  \N   OZ  AAR
# 28  29                               Askari Aviation  \N   4K  AAS
# 29  30                       Australia Asia Airlines  \N  NaN  AAU
# 30  31                       Astro Air International  \N  NaN  AAV
# 31  32                             Afriqiyah Airways  \N   8U  AAW
# 32  33                Afrinat International Airlines  \N   Q9  AFU
# 33  34                             Afric'air Express  \N  NaN  AAX
# 34  35                                 Allegiant Air  \N   G4  AAY
# 35  36                                Angus Aviation  \N  NaN  AAZ
# 36  37                                    Artem-Avia  \N  NaN  ABA
# 37  38          African Business and Transportations  \N  NaN  ABB
# 38  39                                      Aban Air  \N   K5  ABE
# 39  40                                     Aerial Oy  \N  NaN  ABF
# 40  41                                   Abakan-Avia  \N  NaN  ABG
# 41  42                 ABSA - Aerolinhas Brasileiras  \N   M3  TUS
# 42  43                                         Abaet  \N  NaN  ABJ
# 43  44                              Alberta Citylink  \N  NaN  ABK
# 44  45                                 APSA Colombia  \N  NaN  ABO
# 45  46                                Aerovias Bueno  \N  NaN  ABU
# 46  47                                    Aerocenter  \N  NaN  ACR
# 47  48                                    Antrak Air  \N   04  ABV
# 48  49                              Airborne Express  \N   GB  ABX
# 49  50                                       ABX Air  \N   GB  ABX
#
#                                                  \N.1  \
# 0                                                 NaN
# 1                                             GENERAL
# 2                                             NEXTIME
# 3                                                 NaN
# 4                                                 NaN
# 5                                      CHKALOVSK-AVIA
# 6                                          CARGO UNIT
# 7                                        CLOUD RUNNER
# 8                                             SECUREX
# 9                                            MILE-AIR
# 10                                            QUARTET
# 11                                              DONUT
# 12                                             ANSETT
# 13                                                NaN
# 14                                                ABG
# 15                                            ARMYAIR
# 16                                            SUNRISE
# 17                                             ASEISA
# 18                                             BINIZA
# 19                                    ALBATROS ESPANA
# 20                                         AIGLE AZUR
# 21                                              ALOHA
# 22                                      ALASKA ISLAND
# 23                                           AMERICAN
# 24                                            AM CORP
# 25                                       ATLANTIS AIR
# 26                                    AEROVISTA GROUP
# 27                                             ASIANA
# 28                                             AL-AAS
# 29                                           AUSTASIA
# 30                                         ASTRO-PHIL
# 31                                          AFRIQIYAH
# 32                                                NaN
# 33                                              AFREX
# 34                                          ALLEGIANT
# 35                                              ANGUS
# 36                                         ARTEM-AVIA
# 37                                  AFRICAN BUSINESS-
# 38                                               ABAN
# 39                                           SKYWINGS
# 40                                        ABAKAN-AVIA
# 41                                         ABSA Cargo
# 42                                              Abaet
# 43                                   ALBERTA CITYLINK
# 44                                        AEROEXPRESO
# 45                                          AEROBUENO
# 46   Escuela de Formacion de Pioltos Privados de A...
# 47                                             ANTRAK
# 48                                               ABEX
# 49                                               ABEX
#
#                                 \N.2  Y
# 0                                NaN  Y
# 1                      United States  N
# 2                       South Africa  Y
# 3                     United Kingdom  N
# 4                             Russia  N
# 5                             Russia  N
# 6                             Russia  N
# 7                     United Kingdom  N
# 8                      United States  N
# 9                      United States  Y
# 10                          Thailand  N
# 11                            Canada  N
# 12                         Australia  Y
# 13                         Singapore  Y
# 14                           Belgium  N
# 15                    United Kingdom  N
# 16                            Canada  N
# 17                            Mexico  N
# 18                            Mexico  N
# 19                             Spain  N
# 20                            France  Y
# 21                     United States  Y
# 22                     United States  N
# 23                     United States  Y
# 24                     United States  N
# 25                     United States  N
# 26              United Arab Emirates  N
# 27                 Republic of Korea  Y
# 28                          Pakistan  Y
# 29                         Australia  N
# 30                     United States  N
# 31                             Libya  Y
# 32                            Gambia  N
# 33                       Ivory Coast  N
# 34                     United States  Y
# 35                            Canada  N
# 36                           Ukraine  N
# 37  Democratic Republic of the Congo  N
# 38                              Iran  n
# 39                           Finland  N
# 40                            Russia  N
# 41                            Brazil  Y
# 42                            Brazil  N
# 43                            Canada  N
# 44                          Colombia  N
# 45                          Colombia  N
# 46                        AEROCENTER  N
# 47                             Ghana  N
# 48                     United States  N
# 49                     United States  N
